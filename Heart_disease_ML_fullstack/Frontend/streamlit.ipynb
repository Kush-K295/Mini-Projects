# %%
import streamlit as st

# %%
st.title("My First Streamlit App")
# Out:
# 2026-06-30 11:06:47.147 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-30 11:06:47.475
# ...
#   command:
#
#     streamlit run C:\Users\manns\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-30 11:06:47.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-30 11:06:47.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
